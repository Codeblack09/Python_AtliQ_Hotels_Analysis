# %% [markdown]
# <h2 align="center">AtliQ Hotels Data Analysis Project<h2>

# %%
import pandas as pd

# %%
df_bookings = pd.read_csv("fact_bookings.csv")
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
from matplotlib import pyplot as plt
df_bookings.booking_platform.value_counts().plot(kind = "barh")
plt.xticks(rotation = 45)
plt.show()

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.revenue_generated.min(), df_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
df_date = pd.read_csv("dim_date.csv")
df_hotels = pd.read_csv("dim_hotels.csv")
df_rooms = pd.read_csv("dim_rooms.csv")
df_agg_bookings = pd.read_csv("fact_aggregated_bookings.csv")

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().plot(kind = "bar")
plt.xticks(rotation = 45)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Mumbai'),
#   Text(1, 0, 'Hyderabad'),
#   Text(2, 0, 'Bangalore'),
#   Text(3, 0, 'Delhi')])

# %% [markdown]
# ***
# **Explore Aggregated Bookings**
# ***

# %%
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0

# %% [markdown]
# **Exercise 1 : Finding out unique property ids in aggregate bookings dataset**

# %%
df_agg_bookings.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560])

# %% [markdown]
# **Exercise 2 : Finding out total bookings per property_id**

# %%
df_agg_bookings.groupby("property_id")["successful_bookings"].sum()
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %% [markdown]
# **Exercise 3 : Finding out days on which bookings are greater than capacity**

# %%
df_agg_bookings[df_agg_bookings.successful_bookings > df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %% [markdown]
# **Exercise 4 : Finding out properties that have highest capacity**

# %%
df_agg_bookings.capacity.max()
# Out:
# np.float64(50.0)

# %%
df_agg_bookings[df_agg_bookings.capacity == df_agg_bookings.capacity.max()]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %% [markdown]
# ***
# ### -> 2. Data Cleaning ---------------------------------------------------------------------------------------------------------
# ***

# %%
import numpy as np

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %% [markdown]
# **Cleaning Invalid Guests**

# %%
df_bookings[df_bookings.no_guests <= 0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings = df_bookings[df_bookings.no_guests > 0 ]
df_bookings.shape
# Out:
# (134578, 12)

# %%
df_bookings.revenue_generated.min(), df_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
avg, std = df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.std()
avg ,std
# Out:
# (np.float64(15378.036937686695), np.float64(93040.1549314641))

# %%
higher_limit = avg + (3*std)
lower_limit = avg - (3*std)

higher_limit , lower_limit
# Out:
# (np.float64(294498.50173207896), np.float64(-263742.4278567056))

# %%
df_bookings = df_bookings[df_bookings.revenue_generated < higher_limit]

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
h_limit = df_bookings.revenue_realized.mean() + (3*df_bookings.revenue_realized.std())
h_limit
# Out:
# np.float64(33479.358661845814)

# %%
df_bookings[df_bookings.revenue_realized > h_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_bookings[df_bookings.room_category=="RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
23439 + 3*9048
# Out:
# 50583

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# ***
# ### -> 3. Data Transformation -----------------------------------------------------------------------------------------------------
# ***

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings["occ_pct"] = df_agg_bookings["successful_bookings"]/df_agg_bookings["capacity"]

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#     occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667
# 3  1.578947
# 4  0.947368

# %%
df_agg_bookings["occ_pct"] = df_agg_bookings["occ_pct"].apply(lambda x : round(x*100, 2))

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89
# 4    94.74

# %% [markdown]
# ***
# ### -> 4. Insights Generation ------------------------------------------------------------------------------------------------------
# ***

# %% [markdown]
# ### AD_HOC Analysis

# %% [markdown]
# **1. Finding the average occupancy rate in each of the room category?------------------**

# %%
df_agg_bookings.groupby("room_category")["occ_pct"].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occ_pct, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_rn_merged = pd.merge(df_agg_bookings, df_rooms, left_on = "room_category", right_on = "room_id")
df_rn_merged.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_id room_class
# 0    83.33     RT1   Standard
# 1    93.33     RT1   Standard
# 2    76.67     RT1   Standard
# 3   157.89     RT1   Standard
# 4    94.74     RT1   Standard

# %%
df_rn_merged.groupby("room_class")["occ_pct"].mean().round(2)
# Out:
# room_class
# Elite           58.04
# Premium         58.03
# Presidential    59.30
# Standard        58.22
# Name: occ_pct, dtype: float64

# %%
df_rn_merged.drop("room_id", axis = 1, inplace = True)

# %%
df_rn_merged
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occ_pct    room_class
# ...

# %% [markdown]
# **2. Calculating average occupancy rate per city-------------------**

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df_city_merged = pd.merge(df_rn_merged, df_hotels, on = "property_id")
df_city_merged.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct room_class  property_name  category       city
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2    76.67   Standard   Atliq Palace  Business  Bangalore

# %%
df_city_merged.groupby("city")["occ_pct"].mean().round(2)
# Out:
# city
# Bangalore    56.59
# Delhi        61.61
# Hyderabad    58.14
# Mumbai       57.94
# Name: occ_pct, dtype: float64

# %%
dcm = df_city_merged.groupby("city")["occ_pct"].mean().round(2).plot(kind = "bar", color = "teal")
plt.xticks(rotation = 45)

for container in dcm.containers:
    dcm.bar_label(container, fmt='%.2f')  # formats to 2 decimal places

plt.show()

# %% [markdown]
# **3. When was the ocuupancy better on weekends or weekdays?-------------------------**

# %%
df_city_merged.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct room_class  property_name  category       city
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2    76.67   Standard   Atliq Palace  Business  Bangalore

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df_date_merged = pd.merge(df_city_merged, df_date, left_on = "check_in_date", right_on = "date")
df_date_merged.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
#
#    occ_pct room_class property_name  category       city       date  mmm yy  \
# 0    51.72    Premium  Atliq Palace  Business  Bangalore  10-May-22  May 22
# 1    63.33   Standard    Atliq City  Business  Hyderabad  10-May-22  May 22
# 2    60.00   Standard     Atliq Bay    Luxury  Bangalore  10-May-22  May 22
#
#   week no  day_type
# 0    W 20  weekeday
# 1    W 20  weekeday
# 2    W 20  weekeday

# %%
df_date_merged.groupby("day_type")["occ_pct"].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occ_pct, dtype: float64

# %%
df_date_merged.groupby("day_type")["occ_pct"].mean().round(2).plot(kind = "pie", autopct = '%1.1f%%')
plt.show()

# %% [markdown]
# **4. In the month of June, what is the occupancy for different cities---------------------**

# %%
df_date_merged["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_june_22 = df_date_merged[df_date_merged["mmm yy"] == "Jun 22"]
df_june_22.head(3)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        19562     10-Jun-22           RT1                   19      30.0
# 2202        19563     10-Jun-22           RT1                   17      30.0
#
#       occ_pct room_class  property_name  category       city       date  \
# 2200    66.67   Standard  Atliq Exotica    Luxury     Mumbai  10-Jun-22
# 2201    63.33   Standard      Atliq Bay    Luxury  Bangalore  10-Jun-22
# 2202    56.67   Standard   Atliq Palace  Business  Bangalore  10-Jun-22
#
#       mmm yy week no  day_type
# 2200  Jun 22    W 24  weekeday
# 2201  Jun 22    W 24  weekeday
# 2202  Jun 22    W 24  weekeday

# %%
df_june_22.groupby("city")["occ_pct"].mean().round(2).sort_values(ascending = False)
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.58
# Name: occ_pct, dtype: float64

# %% [markdown]
# **5. Adding latest data to existing dataframe---------------------------------------------**

# %%
df_august = pd.read_csv("new_data_august.csv")
df_august.head(3)
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67

# %%
df_date_merged.columns
# Out:
# Index(['property_id', 'check_in_date', 'room_category', 'successful_bookings',
#        'capacity', 'occ_pct', 'room_class', 'property_name', 'category',
#        'city', 'date', 'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
df_august.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df_date_merged.drop("date", axis = 1, inplace = True)

# %%
df_date_merged.shape
# Out:
# (6500, 13)

# %%
df_august.shape
# Out:
# (7, 13)

# %%
df_latest = pd.concat([df_date_merged, df_august], ignore_index = True, axis = 0)
df_latest.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6497        17558     31-Jul-22           RT4                    3       6.0
# 6498        19563     31-Jul-22           RT4                    3       6.0
# 6499        17561     31-Jul-22           RT4                    3       4.0
# 6500        16559     01-Aug-22           RT1                   30      30.0
# 6501        19562     01-Aug-22           RT1                   21      30.0
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       occ_pct    room_class  property_name  category       city  mmm yy  \
# ...

# %%
df_latest.shape
# Out:
# (6507, 14)

# %% [markdown]
# **6. Finding revenue realized per city----------------------------------------------------**

# %%
df_bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 1               9100              3640
# 4              10920             10920
# 5               9100              9100
# 6               9100              3640

# %%
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df_boho_merged = pd.merge(df_bookings, df_hotels, on = "property_id")
df_boho_merged.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# ...

# %%
df_boho_merged.groupby("city")["revenue_realized"].sum()
# Out:
# city
# Bangalore    420383550
# Delhi        294404488
# Hyderabad    325179310
# Mumbai       668569251
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **7. Finding month by month revenue-------------------------------------------------------**

# %%
df_boho_merged.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi

# %%
df_date["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday

# %%
pd.merge(df_boho_merged, df_date, left_on = "check_in_date", right_on = "date")
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized, property_name, category, city, date, mmm yy, week no, day_type]
# Index: []

# %%
df_boho_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  object
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
df_date["date"] = pd.to_datetime(df_date["date"], dayfirst = True, errors = 'coerce' )
df_date.head(3)
# Out:
# C:\Users\Rentex\AppData\Local\Temp\ipykernel_10604\1282720820.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_date["date"] = pd.to_datetime(df_date["date"], dayfirst = True, errors = 'coerce' )
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     datetime64[ns]
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ KB

# %%
df_boho_merged["check_in_date"] = pd.to_datetime(df_boho_merged["check_in_date"], dayfirst=True, errors='coerce')

# %%
df_boho_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      55790 non-null   datetime64[ns]
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
pd.merge(df_boho_merged, df_date, left_on = "check_in_date", right_on = "date")
# Out:
#              booking_id  property_id booking_date check_in_date checkout_date  \
# 0      May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1      May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2      May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
# 3      May012216558RT17        16558     28-04-22    2022-05-01      6/5/2022
# 4      May012216558RT18        16558     26-04-22    2022-05-01      3/5/2022
# ...                 ...          ...          ...           ...           ...
# 55785  Jul122217564RT43        17564    11/7/2022    2022-07-12      16-07-22
# 55786  Jul122217564RT44        17564    11/7/2022    2022-07-12      14-07-22
# 55787  Jul122217564RT45        17564    12/7/2022    2022-07-12      13-07-22
# 55788  Jul122217564RT46        17564     6/7/2022    2022-07-12      13-07-22
# 55789  Jul122217564RT47        17564    10/7/2022    2022-07-12      16-07-22
#
# ...

# %%
df_boho_date_merged = pd.merge(df_boho_merged, df_date, left_on = "check_in_date", right_on = "date")
df_boho_date_merged.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
# 3  May012216558RT17        16558     28-04-22    2022-05-01      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# ...

# %%
df_boho_date_merged.groupby("mmm yy")["revenue_realized"].sum()
# Out:
# mmm yy
# Jul 22    243180932
# Jun 22    229637640
# May 22    234353183
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **8. Finding revenue realized per hotel type----------------------------------------------**

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_boho_merged.groupby("category")["revenue_realized"].sum()
# Out:
# category
# Business     655967037
# Luxury      1052569562
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **9. Finding the average rating per city**

# %%
df_boho_merged.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
# 3  May012216558RT17        16558     28-04-22    2022-05-01      6/5/2022
# 4  May012216558RT18        16558     26-04-22    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_boho_merged.groupby("city")["ratings_given"].mean().round(2)
# Out:
# city
# Bangalore    3.41
# Delhi        3.78
# Hyderabad    3.66
# Mumbai       3.65
# Name: ratings_given, dtype: float64

# %% [markdown]
# **10. Printing a Pie Chart of revenue realized per platform-------------------------------**

# %%
df_boho_merged.groupby("booking_platform")["revenue_realized"].sum().plot(kind = "pie", autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='revenue_realized'>
